# %% [markdown]
# <a href="https://colab.research.google.com/github/ApoorvaNamala/Credit-Card-Fraud-Detection/blob/master/CreditCardFraudDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import pylab as py
import seaborn as sns
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn import metrics
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data=pd.read_csv('/content/drive/My Drive/creditcard.csv')
data
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
print('No Frauds =', round(data['Class'].value_counts()[0]/len(data) * 100,2),"%")
print('Frauds =', round(data['Class'].value_counts()[1]/len(data) * 100,2),"%")
# Out:
# No Frauds = 99.83 %
# Frauds = 0.17 %

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

amount_val = data['Amount'].values
time_val = data['Time'].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])



plt.show()

# %%
colors = ["blue", "red"]
sns.countplot('Class', data=data, palette=colors)

# %%
print("No.of frauds = ",data['Class'].value_counts()[1])
# Out:
# No.of frauds =  492

# %%
from sklearn.preprocessing import RobustScaler

# %%
rob_scaler = RobustScaler()
data['scaled_amount'] = rob_scaler.fit_transform(data['Amount'].values.reshape(-1,1))

# %%
data['scaled_time'] = rob_scaler.fit_transform(data['Time'].values.reshape(-1,1))

# %%
data.drop(['Time','Amount'], axis=1, inplace=True)
data.head()
# Out:
#          V1        V2        V3  ...  Class  scaled_amount  scaled_time
# 0 -1.359807 -0.072781  2.536347  ...      0       1.783274    -0.994983
# 1  1.191857  0.266151  0.166480  ...      0      -0.269825    -0.994983
# 2 -1.358354 -1.340163  1.773209  ...      0       4.983721    -0.994972
# 3 -0.966272 -0.185226  1.792993  ...      0       1.418291    -0.994972
# 4 -1.158233  0.877737  1.548718  ...      0       0.670579    -0.994960
#
# [5 rows x 31 columns]

# %%
corrmat = data.corr() 
fig = plt.figure(figsize = (12, 9)) 
sns.heatmap(corrmat, vmax = .8, square = True) 
plt.show()

# %%
X = data.drop(['Class'], axis = 1) 
Y = data["Class"] 
print(X.shape) 
print(Y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
data = data.sample(frac=1)
fraud_data = data.loc[data['Class'] == 1]
non_fraud_data = data.loc[data['Class'] == 0][:492]
normal_distributed_data = pd.concat([fraud_data, non_fraud_data])
new_data = normal_distributed_data.sample(frac=1, random_state=42)
new_data
# Out:
#               V1        V2        V3  ...  Class  scaled_amount  scaled_time
# 61924   0.821819 -1.037763  0.796493  ...      0       2.172011    -0.406995
# 263877 -3.387601  3.977881 -6.978585  ...      1      -0.302103     0.898295
# 71614   1.382499 -1.656348  0.917962  ...      0       0.391253    -0.356289
# 79835   0.340391  2.015233 -2.777330  ...      1      -0.282960    -0.311247
# 137705 -1.464897  1.975528 -1.077145  ...      1      -0.293440    -0.028231
# ...          ...       ...       ...  ...    ...            ...          ...
# 6472    1.023874  2.001485 -4.769752  ...      1      -0.293440    -0.904052
# 99506  -1.824295  0.403327 -1.994122  ...      1       6.535457    -0.206088
# 8823    1.280878  0.351711  0.565492  ...      0      -0.211416    -0.853417
# 263324 -0.848290  2.719882 -6.199070  ...      1       1.469154     0.895253
# 149869 -1.108478  3.448953 -6.216972  ...      1      -0.055893     0.086937
#
# [984 rows x 31 columns]

# %%
colors = ["blue", "red"]
sns.countplot('Class', data=new_data, palette=colors)

# %%
corrmat = new_data.corr() 
fig = plt.figure(figsize = (12, 9)) 
sns.heatmap(corrmat, vmax = .8, square = True) 
plt.show()

# %%
f, (ax2) = plt.subplots( 1, figsize=(24,20))
sub_sample_corr = new_data.corr()
sns.heatmap(sub_sample_corr, cmap='coolwarm_r', annot_kws={'size':20}, ax=ax2)
ax2.set_title('SubSample Correlation Matrix ', fontsize=14)
plt.show()

# %%
X = new_data.drop('Class', axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import collections

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test,y_test)
# Out:
# 0.9324324324324325

# %% [markdown]
# # KNN

# %%
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train, y_train)
y_pred=knn.predict(X_test)
acc_score=metrics.accuracy_score(y_test,y_pred) 
print("Accuracy of Test:", acc_score)
# Out:
# Accuracy of Test: 0.9222972972972973

# %% [markdown]
# # Decision Tree Classifier

# %%
dtree=DecisionTreeClassifier(criterion='entropy',max_depth=3)
dtree.fit(X_train,y_train)
y_pred=dtree.predict(X_test)
acc_score=metrics.accuracy_score(y_test,y_pred)
print("Accuracy of Test:", acc_score)
# Out:
# Accuracy of Test: 0.9054054054054054

# %% [markdown]
# # SVM

# %%
svm = SVC()
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
acc_score=metrics.accuracy_score(y_test,y_pred)
print("Accuracy of Test:", acc_score)
# Out:
# Accuracy of Test: 0.9290540540540541

# %% [markdown]
# #NEURAL NETWORKS

# %%
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
n_inputs = X_train.shape[1]

classifier = Sequential([
    Dense(n_inputs, input_shape=(n_inputs, ), activation='relu'),
    Dense(32, activation='relu'),
    Dense(2, activation='softmax')
])
classifier.compile(Adam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train, y_train, validation_split=0.2, batch_size=300, epochs=100, shuffle=True, verbose=2)
# Out:
# Train on 550 samples, validate on 138 samples
# Epoch 1/100
#  - 0s - loss: 1.3021 - accuracy: 0.3709 - val_loss: 1.0438 - val_accuracy: 0.3333
# Epoch 2/100
#  - 0s - loss: 0.9875 - accuracy: 0.4218 - val_loss: 0.8067 - val_accuracy: 0.4275
# Epoch 3/100
#  - 0s - loss: 0.7676 - accuracy: 0.5527 - val_loss: 0.6718 - val_accuracy: 0.5652
# Epoch 4/100
#  - 0s - loss: 0.6466 - accuracy: 0.6182 - val_loss: 0.5948 - val_accuracy: 0.6087
# Epoch 5/100
#  - 0s - loss: 0.5775 - accuracy: 0.6418 - val_loss: 0.5435 - val_accuracy: 0.6377
# Epoch 6/100
#  - 0s - loss: 0.5325 - accuracy: 0.6727 - val_loss: 0.5059 - val_accuracy: 0.7029
# Epoch 7/100
#  - 0s - loss: 0.5018 - accuracy: 0.7000 - val_loss: 0.4768 - val_accuracy: 0.7029
# Epoch 8/100
#  - 0s - loss: 0.4782 - accuracy: 0.7309 - val_loss: 0.4531 - val_accuracy: 0.7246
# Epoch 9/100
#  - 0s - loss: 0.4591 - accuracy: 0.7491 - val_loss: 0.4330 - val_accuracy: 0.7464
# Epoch 10/100
#  - 0s - loss: 0.4410 - accuracy: 0.7727 - val_loss: 0.4157 - val_accuracy: 0.7826
# Epoch 11/100
#  - 0s - loss: 0.4243 - accuracy: 0.7873 - val_loss: 0.4002 - val_accuracy: 0.7899
# Epoch 12/100
#  - 0s - loss: 0.4092 - accuracy: 0.8236 - val_loss: 0.3861 - val_accuracy: 0.8696
# Epoch 13/100
#  - 0s - loss: 0.3950 - accuracy: 0.8309 - val_loss: 0.3734 - val_accuracy: 0.8913
# Epoch 14/100
#  - 0s - loss: 0.3815 - accuracy: 0.8418 - val_loss: 0.3620 - val_accuracy: 0.9058
# Epoch 15/100
#  - 0s - loss: 0.3688 - accuracy: 0.8600 - val_loss: 0.3513 - val_accuracy: 0.9058
# Epoch 16/100
#  - 0s - loss: 0.3575 - accuracy: 0.8764 - val_loss: 0.3414 - val_accuracy: 0.8986
# Epoch 17/100
#  - 0s - loss: 0.3464 - accuracy: 0.8891 - val_loss: 0.3322 - val_accuracy: 0.9130
# Epoch 18/100
#  - 0s - loss: 0.3353 - accuracy: 0.9018 - val_loss: 0.3235 - val_accuracy: 0.9203
# Epoch 19/100
#  - 0s - loss: 0.3252 - accuracy: 0.9145 - val_loss: 0.3152 - val_accuracy: 0.9203
# Epoch 20/100
#  - 0s - loss: 0.3157 - accuracy: 0.9218 - val_loss: 0.3075 - val_accuracy: 0.9275
# Epoch 21/100
#  - 0s - loss: 0.3063 - accuracy: 0.9273 - val_loss: 0.3001 - val_accuracy: 0.9275
# Epoch 22/100
#  - 0s - loss: 0.2974 - accuracy: 0.9309 - val_loss: 0.2929 - val_accuracy: 0.9203
# Epoch 23/100
#  - 0s - loss: 0.2886 - accuracy: 0.9309 - val_loss: 0.2858 - val_accuracy: 0.9203
# Epoch 24/100
#  - 0s - loss: 0.2804 - accuracy: 0.9382 - val_loss: 0.2791 - val_accuracy: 0.9203
# Epoch 25/100
#  - 0s - loss: 0.2724 - accuracy: 0.9436 - val_loss: 0.2725 - val_accuracy: 0.9203
# Epoch 26/100
#  - 0s - loss: 0.2645 - accuracy: 0.9418 - val_loss: 0.2662 - val_accuracy: 0.9203
# Epoch 27/100
#  - 0s - loss: 0.2569 - accuracy: 0.9436 - val_loss: 0.2603 - val_accuracy: 0.9203
# Epoch 28/100
#  - 0s - loss: 0.2497 - accuracy: 0.9455 - val_loss: 0.2548 - val_accuracy: 0.9203
# Epoch 29/100
#  - 0s - loss: 0.2427 - accuracy: 0.9455 - val_loss: 0.2498 - val_accuracy: 0.9203
# Epoch 30/100
#  - 0s - loss: 0.2361 - accuracy: 0.9455 - val_loss: 0.2448 - val_accuracy: 0.9203
# Epoch 31/100
#  - 0s - loss: 0.2296 - accuracy: 0.9455 - val_loss: 0.2403 - val_accuracy: 0.9203
# Epoch 32/100
#  - 0s - loss: 0.2234 - accuracy: 0.9436 - val_loss: 0.2359 - val_accuracy: 0.9203
# Epoch 33/100
#  - 0s - loss: 0.2176 - accuracy: 0.9436 - val_loss: 0.2318 - val_accuracy: 0.9203
# Epoch 34/100
#  - 0s - loss: 0.2119 - accuracy: 0.9436 - val_loss: 0.2278 - val_accuracy: 0.9203
# Epoch 35/100
#  - 0s - loss: 0.2065 - accuracy: 0.9436 - val_loss: 0.2242 - val_accuracy: 0.9203
# Epoch 36/100
#  - 0s - loss: 0.2015 - accuracy: 0.9436 - val_loss: 0.2209 - val_accuracy: 0.9203
# Epoch 37/100
#  - 0s - loss: 0.1966 - accuracy: 0.9455 - val_loss: 0.2177 - val_accuracy: 0.9275
# Epoch 38/100
#  - 0s - loss: 0.1918 - accuracy: 0.9455 - val_loss: 0.2149 - val_accuracy: 0.9275
# Epoch 39/100
#  - 0s - loss: 0.1874 - accuracy: 0.9455 - val_loss: 0.2123 - val_accuracy: 0.9275
# Epoch 40/100
#  - 0s - loss: 0.1834 - accuracy: 0.9455 - val_loss: 0.2098 - val_accuracy: 0.9275
# Epoch 41/100
#  - 0s - loss: 0.1793 - accuracy: 0.9455 - val_loss: 0.2075 - val_accuracy: 0.9275
# Epoch 42/100
#  - 0s - loss: 0.1756 - accuracy: 0.9455 - val_loss: 0.2054 - val_accuracy: 0.9275
# Epoch 43/100
#  - 0s - loss: 0.1720 - accuracy: 0.9455 - val_loss: 0.2034 - val_accuracy: 0.9275
# Epoch 44/100
#  - 0s - loss: 0.1685 - accuracy: 0.9455 - val_loss: 0.2014 - val_accuracy: 0.9275
# Epoch 45/100
#  - 0s - loss: 0.1654 - accuracy: 0.9473 - val_loss: 0.1997 - val_accuracy: 0.9275
# Epoch 46/100
#  - 0s - loss: 0.1621 - accuracy: 0.9455 - val_loss: 0.1980 - val_accuracy: 0.9275
# Epoch 47/100
#  - 0s - loss: 0.1593 - accuracy: 0.9455 - val_loss: 0.1964 - val_accuracy: 0.9275
# Epoch 48/100
#  - 0s - loss: 0.1564 - accuracy: 0.9455 - val_loss: 0.1950 - val_accuracy: 0.9275
# Epoch 49/100
#  - 0s - loss: 0.1537 - accuracy: 0.9473 - val_loss: 0.1938 - val_accuracy: 0.9275
# Epoch 50/100
#  - 0s - loss: 0.1509 - accuracy: 0.9473 - val_loss: 0.1927 - val_accuracy: 0.9203
# Epoch 51/100
#  - 0s - loss: 0.1484 - accuracy: 0.9473 - val_loss: 0.1917 - val_accuracy: 0.9203
# Epoch 52/100
#  - 0s - loss: 0.1460 - accuracy: 0.9491 - val_loss: 0.1909 - val_accuracy: 0.9203
# Epoch 53/100
#  - 0s - loss: 0.1436 - accuracy: 0.9491 - val_loss: 0.1900 - val_accuracy: 0.9203
# Epoch 54/100
#  - 0s - loss: 0.1414 - accuracy: 0.9491 - val_loss: 0.1891 - val_accuracy: 0.9203
# Epoch 55/100
#  - 0s - loss: 0.1391 - accuracy: 0.9491 - val_loss: 0.1884 - val_accuracy: 0.9203
# Epoch 56/100
#  - 0s - loss: 0.1370 - accuracy: 0.9491 - val_loss: 0.1877 - val_accuracy: 0.9203
# Epoch 57/100
#  - 0s - loss: 0.1350 - accuracy: 0.9509 - val_loss: 0.1871 - val_accuracy: 0.9203
# Epoch 58/100
#  - 0s - loss: 0.1330 - accuracy: 0.9509 - val_loss: 0.1864 - val_accuracy: 0.9203
# Epoch 59/100
#  - 0s - loss: 0.1311 - accuracy: 0.9527 - val_loss: 0.1859 - val_accuracy: 0.9203
# Epoch 60/100
#  - 0s - loss: 0.1292 - accuracy: 0.9527 - val_loss: 0.1853 - val_accuracy: 0.9203
# Epoch 61/100
#  - 0s - loss: 0.1274 - accuracy: 0.9527 - val_loss: 0.1848 - val_accuracy: 0.9203
# Epoch 62/100
#  - 0s - loss: 0.1257 - accuracy: 0.9527 - val_loss: 0.1845 - val_accuracy: 0.9203
# Epoch 63/100
#  - 0s - loss: 0.1239 - accuracy: 0.9527 - val_loss: 0.1841 - val_accuracy: 0.9203
# Epoch 64/100
#  - 0s - loss: 0.1223 - accuracy: 0.9527 - val_loss: 0.1838 - val_accuracy: 0.9203
# Epoch 65/100
#  - 0s - loss: 0.1208 - accuracy: 0.9527 - val_loss: 0.1834 - val_accuracy: 0.9203
# Epoch 66/100
#  - 0s - loss: 0.1193 - accuracy: 0.9527 - val_loss: 0.1830 - val_accuracy: 0.9203
# Epoch 67/100
#  - 0s - loss: 0.1178 - accuracy: 0.9527 - val_loss: 0.1826 - val_accuracy: 0.9203
# Epoch 68/100
#  - 0s - loss: 0.1164 - accuracy: 0.9545 - val_loss: 0.1824 - val_accuracy: 0.9203
# Epoch 69/100
#  - 0s - loss: 0.1151 - accuracy: 0.9545 - val_loss: 0.1821 - val_accuracy: 0.9203
# Epoch 70/100
#  - 0s - loss: 0.1136 - accuracy: 0.9545 - val_loss: 0.1818 - val_accuracy: 0.9203
# Epoch 71/100
#  - 0s - loss: 0.1123 - accuracy: 0.9564 - val_loss: 0.1817 - val_accuracy: 0.9203
# Epoch 72/100
#  - 0s - loss: 0.1110 - accuracy: 0.9582 - val_loss: 0.1815 - val_accuracy: 0.9203
# Epoch 73/100
#  - 0s - loss: 0.1097 - accuracy: 0.9582 - val_loss: 0.1813 - val_accuracy: 0.9203
# Epoch 74/100
#  - 0s - loss: 0.1085 - accuracy: 0.9582 - val_loss: 0.1812 - val_accuracy: 0.9203
# Epoch 75/100
#  - 0s - loss: 0.1073 - accuracy: 0.9582 - val_loss: 0.1810 - val_accuracy: 0.9203
# Epoch 76/100
#  - 0s - loss: 0.1060 - accuracy: 0.9582 - val_loss: 0.1808 - val_accuracy: 0.9203
# Epoch 77/100
#  - 0s - loss: 0.1049 - accuracy: 0.9600 - val_loss: 0.1806 - val_accuracy: 0.9203
# Epoch 78/100
#  - 0s - loss: 0.1037 - accuracy: 0.9600 - val_loss: 0.1804 - val_accuracy: 0.9203
# Epoch 79/100
#  - 0s - loss: 0.1026 - accuracy: 0.9600 - val_loss: 0.1802 - val_accuracy: 0.9203
# Epoch 80/100
#  - 0s - loss: 0.1015 - accuracy: 0.9600 - val_loss: 0.1800 - val_accuracy: 0.9203
# Epoch 81/100
#  - 0s - loss: 0.1004 - accuracy: 0.9600 - val_loss: 0.1799 - val_accuracy: 0.9203
# Epoch 82/100
#  - 0s - loss: 0.0993 - accuracy: 0.9600 - val_loss: 0.1797 - val_accuracy: 0.9203
# Epoch 83/100
#  - 0s - loss: 0.0983 - accuracy: 0.9618 - val_loss: 0.1796 - val_accuracy: 0.9203
# Epoch 84/100
#  - 0s - loss: 0.0972 - accuracy: 0.9618 - val_loss: 0.1794 - val_accuracy: 0.9203
# Epoch 85/100
#  - 0s - loss: 0.0962 - accuracy: 0.9618 - val_loss: 0.1792 - val_accuracy: 0.9203
# Epoch 86/100
#  - 0s - loss: 0.0951 - accuracy: 0.9618 - val_loss: 0.1792 - val_accuracy: 0.9275
# Epoch 87/100
#  - 0s - loss: 0.0942 - accuracy: 0.9618 - val_loss: 0.1791 - val_accuracy: 0.9275
# Epoch 88/100
#  - 0s - loss: 0.0933 - accuracy: 0.9636 - val_loss: 0.1789 - val_accuracy: 0.9275
# Epoch 89/100
#  - 0s - loss: 0.0923 - accuracy: 0.9636 - val_loss: 0.1787 - val_accuracy: 0.9275
# Epoch 90/100
#  - 0s - loss: 0.0913 - accuracy: 0.9636 - val_loss: 0.1786 - val_accuracy: 0.9275
# Epoch 91/100
#  - 0s - loss: 0.0904 - accuracy: 0.9636 - val_loss: 0.1785 - val_accuracy: 0.9275
# Epoch 92/100
#  - 0s - loss: 0.0895 - accuracy: 0.9636 - val_loss: 0.1784 - val_accuracy: 0.9275
# Epoch 93/100
#  - 0s - loss: 0.0886 - accuracy: 0.9636 - val_loss: 0.1784 - val_accuracy: 0.9275
# Epoch 94/100
#  - 0s - loss: 0.0877 - accuracy: 0.9636 - val_loss: 0.1785 - val_accuracy: 0.9275
# Epoch 95/100
#  - 0s - loss: 0.0868 - accuracy: 0.9636 - val_loss: 0.1785 - val_accuracy: 0.9275
# Epoch 96/100
#  - 0s - loss: 0.0860 - accuracy: 0.9655 - val_loss: 0.1786 - val_accuracy: 0.9275
# Epoch 97/100
#  - 0s - loss: 0.0851 - accuracy: 0.9655 - val_loss: 0.1788 - val_accuracy: 0.9275
# Epoch 98/100
#  - 0s - loss: 0.0843 - accuracy: 0.9655 - val_loss: 0.1789 - val_accuracy: 0.9275
# Epoch 99/100
#  - 0s - loss: 0.0835 - accuracy: 0.9655 - val_loss: 0.1791 - val_accuracy: 0.9275
# Epoch 100/100
#  - 0s - loss: 0.0827 - accuracy: 0.9655 - val_loss: 0.1793 - val_accuracy: 0.9275
